# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafiz-07/Data/blob/main/kaggle_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('train_dataset.csv')
df_test=pd.read_csv('test_dataset_exam.csv')

# %%
df.shape
# Out:
# (51952, 25)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
features=['Age','Gender','Baggage handling',  'Customer Type','Type of Travel','Class', 'Flight Distance', 'Inflight wifi service','Departure/Arrival time convenient', 'Ease of Online booking','Online boarding', 'Seat comfort','Inflight entertainment','Food and drink', 'On-board service', 'Leg room service','Departure Delay in Minutes', 'Arrival Delay in Minutes']

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df_test.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# ...

# %%
df.dropna(inplace=True)
df_test['Arrival Delay in Minutes']=df_test['Arrival Delay in Minutes'].fillna(df_test['Arrival Delay in Minutes'].mean())
df_test.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
df.shape
# Out:
# (51791, 25)

# %%
df_test.shape
# Out:
# (25976, 24)

# %%
X_train=df[features]
X_test=df_test[features]
y_train=df['satisfaction']

# %%
X_train.head()
# Out:
#    Age  Gender  Baggage handling   Customer Type   Type of Travel     Class  \
# 0   28  Female                 5  Loyal Customer  Business travel  Business
# 1   42  Female                 4  Loyal Customer  Business travel  Business
# 2   28    Male                 2  Loyal Customer  Personal Travel       Eco
# 3   24    Male                 3  Loyal Customer  Personal Travel  Business
# 4   45    Male                 2  Loyal Customer  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             2586                      5                                  5
# 1              507                      3                                  3
# 2              113                      3                                  1
# 3              818                      2                                  5
# 4              236                      2                                  5
#
# ...

# %%
categorical_cols = ['Type of Travel', 'Class','Gender','Customer Type']

for col in categorical_cols:
  X_train[col] = X_train[col].astype('category').cat.codes
  X_test[col] = X_test[col].astype('category').cat.codes

X_train.tail()
# Out:
# /tmp/ipython-input-239-820416951.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[col] = X_train[col].astype('category').cat.codes
# /tmp/ipython-input-239-820416951.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[col] = X_test[col].astype('category').cat.codes
# /tmp/ipython-input-239-820416951.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Create and train the logistic regression model
model = LogisticRegression(max_iter=10000, random_state=42)
model.fit(X_train, y_train)

# Predict on the training set
y_train_pred = model.predict(X_train)

# Predict on the test set
y_test_pred = model.predict(X_test)

# Calculate accuracy on the training set
train_accuracy = accuracy_score(y_train, y_train_pred)
print(f'Accuracy on training set: {train_accuracy}')
# Out:
# Accuracy on training set: 0.8707883609121276

# %%
print(y_test_pred)
# Out:
# ['satisfied' 'satisfied' 'neutral or dissatisfied' ...
#  'neutral or dissatisfied' 'satisfied' 'neutral or dissatisfied']

# %%
test_predictions_df = pd.DataFrame({'ID': df_test['id'], 'satisfaction': y_test_pred})


print(test_predictions_df.head())
# Out:
#       ID             satisfaction
# 0  19556                satisfied
# 1  90035                satisfied
# 2  12360  neutral or dissatisfied
# 3  77959  neutral or dissatisfied
# 4  36875  neutral or dissatisfied

# %%
test_predictions_df.to_csv('test_predictions.csv', index=False)

# %%
from google.colab import files

# %%
files.download('test_predictions.csv')

# %%
y_test_pred.shape
# Out:
# (25976,)
